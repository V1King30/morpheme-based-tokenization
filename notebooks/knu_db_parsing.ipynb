# %%
import pandas as pd

pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Shevchenko db part

# %%
shev_words = pd.read_csv('../data/raw/shev4_words.txt', delimiter='\t', encoding='utf-16')

# %%
shev_words
# Out:
#        morfemid  wrdFK mname   mseg
# 0             1     20     R    аби
# 1             2     21     R    аби
# 2             3     21     X    -то
# 3             4     23     R    або
# 4             5     24     R    або
# ...         ...    ...   ...    ...
# 16253     15967   6731     F     ти
# 16254     15968   6732     R  шинок
# 16255     15969   6733     R  шиноч
# 16256     15970   6733     S     ок
# 16257     15971   6734     R    шир
#
# [16258 rows x 4 columns]

# %%
grouped_shev_words = shev_words.groupby('wrdFK').agg({'mname': list, 'mseg': list}).reset_index()

# %%
grouped_shev_words['merged_morphemes'] = grouped_shev_words['mseg'].apply(lambda x: '/'.join(x))

# %%
grouped_shev_words.head()
# Out:
#    wrdFK      mname         mseg merged_morphemes
# 0     20        [R]        [аби]              аби
# 1     21     [R, X]   [аби, -то]          аби/-то
# 2     23        [R]        [або]              або
# 3     24  [R, R, F]  [або, щ, о]          або/щ/о
# 4     26        [R]     [авраам]           авраам

# %%
len(grouped_shev_words)
# Out:
# 5328

# %%
# grouped_shev_words.to_csv('../data/processed/shev4_words.csv', encoding='utf-8', index=False)

# %% [markdown]
# ## Full db

# %%
knu_morphemes_words = pd.read_csv('../data/raw/morfems-knu.txt', delimiter='\t', encoding='utf-8')

# %%
knu_morphemes_words
# Out:
#         morfemid   wrdFK mname  mseg
# 0         706262       2     F    ти
# 1         706261       2     R    бу
# 2         706265       4     F    ти
# 3         706263       4     P     в
# 4         706264       4     R    ви
# ...          ...     ...   ...   ...
# 781162   1534158  221586     F     0
# 781163   1534154  221586     P    до
# 781164   1534155  221586     R  цiль
# 781165   1534156  221586     S     н
# 781166   1534157  221586     S     о
#
# [781167 rows x 4 columns]

# %%
grouped_knu_morphemes_words = knu_morphemes_words \
    .sort_values(by=['wrdFK', 'morfemid'], ascending=[True, True]) \
    .groupby('wrdFK') \
    .agg({'mname': list, 'mseg': list}) \
    .reset_index()

# %%
grouped_knu_morphemes_words.head()
# Out:
#    wrdFK      mname         mseg
# 0      2     [R, F]     [бу, ти]
# 1      4  [P, R, F]  [в, ви, ти]
# 2      5     [R, F]    [вівц, я]
# 3      6        [R]        [він]
# 4      7        [R]       [вісь]

# %%
grouped_knu_morphemes_words['merged_morphemes'] = grouped_knu_morphemes_words['mseg'].apply(lambda x: '/'.join(x))

# %%
grouped_knu_morphemes_words.head(50)
# Out:
#     wrdFK         mname                 mseg merged_morphemes
# 0       2        [R, F]             [бу, ти]            бу/ти
# 1       4     [P, R, F]          [в, ви, ти]          в/ви/ти
# 2       5        [R, F]            [вівц, я]           вівц/я
# 3       6           [R]                [він]              він
# 4       7           [R]               [вісь]             вісь
# 5       8     [P, R, F]          [в, ли, ти]          в/ли/ти
# 6       9  [P, R, F, X]      [в, ли, ти, ся]       в/ли/ти/ся
# 7      10        [R, F]             [вон, а]            вон/а
# 8      11        [R, F]             [вон, и]            вон/и
# 9      12        [R, F]             [вон, о]            вон/о
# 10     13        [R, F]             [вух, о]            вух/о
# 11     14     [R, S, F]          [гн, а, ти]          гн/а/ти
# 12     15     [R, S, F]           [гр, 0, а]           гр/0/а
# 13     16        [R, F]               [м, и]              м/и
# 14     17           [R]               [овес]             овес
# 15     18     [R, S, F]          [сл, а, ти]          сл/а/ти
# 16     19  [R, S, F, X]      [сл, а, ти, ся]       сл/а/ти/ся
# 17     20     [P, R, F]          [с, пи, ти]          с/пи/ти
# 18     21  [P, R, F, X]      [с, пи, ти, ся]       с/пи/ти/ся
# 19     22     [P, R, F]         [с, тер, ти]         с/тер/ти
# 20     23  [P, R, F, X]     [с, тер, ти, ся]      с/тер/ти/ся
# 21     24     [P, R, F]          [с, тя, ти]          с/тя/ти
# 22     25     [R, F, X]        [узя, ти, ся]        узя/ти/ся
# 23     26        [R, F]            [узя, ти]           узя/ти
# 24     27        [R, F]              [хт, о]             хт/о
# 25     28  [R, F, P, R]   [хт, о, -не, будь]    хт/о/-не/будь
# 26     30     [R, F, X]          [хт, о, сь]          хт/о/сь
# 27     31        [R, F]               [щ, о]              щ/о
# 28     32  [R, F, P, R]    [щ, о, -не, будь]     щ/о/-не/будь
# 29     33     [R, F, X]           [щ, о, сь]           щ/о/сь
# 30     35        [R, F]               [j, а]              j/а
# 31     36           [R]                  [а]                а
# 32     38           [R]                [ага]              ага
# 33     39           [R]                  [3]                3
# 34     40           [R]                 [а.]               а.
# 35     41  [R, S, S, F]   [абjур, ац, іj, а]    абjур/ац/іj/а
# 36     42        [R, F]            [абак, а]           абак/а
# 37     43           [R]             [абажур]           абажур
# 38     44           [S]                  [а]                а
# 39     45        [R, S]        [абажур, чик]       абажур/чик
# 40     46           [R]               [абаз]             абаз
# 41     47        [R, S]           [абаз, ин]          абаз/ин
# 42     48     [R, S, S]      [абаз, ин, ець]      абаз/ин/ець
# 43     49  [R, S, S, F]     [абаз, ин, к, а]      абаз/ин/к/а
# 44     50  [R, S, S, F]  [абаз, ин, ськ, ий]   абаз/ин/ськ/ий
# 45     51     [R, S, F]        [абаз, іj, а]        абаз/іj/а
# 46     52           [R]               [абак]             абак
# 47     53        [R, S]           [абак, ан]          абак/ан
# 48     54     [R, S, F]        [абак, ан, 1]        абак/ан/1
# 49     55  [R, S, S, F]  [абак, ан, ськ, ий]   абак/ан/ськ/ий

# %%
len(grouped_knu_morphemes_words)
# Out:
# 199890

# %%
# grouped_knu_morphemes_words.to_csv('../files/knu_morphemes_words.csv', encoding='utf-8', index=False)

# %% [markdown]
# ## Merge together

# %%
morphemes_words = pd.concat([grouped_shev_words, grouped_knu_morphemes_words], axis=0)

# %%
morphemes_words.head()
# Out:
#    wrdFK      mname         mseg merged_morphemes
# 0     20        [R]        [аби]              аби
# 1     21     [R, X]   [аби, -то]          аби/-то
# 2     23        [R]        [або]              або
# 3     24  [R, R, F]  [або, щ, о]          або/щ/о
# 4     26        [R]     [авраам]           авраам

# %%
len(morphemes_words)
# Out:
# 205218

# %%
morphemes_list = morphemes_words['merged_morphemes'].tolist()

# %%
morphemes_list[:10]
# Out:
# ['аби',
#  'аби/-то',
#  'або',
#  'або/щ/о',
#  'авраам',
#  'агар/ян/ськ/ий',
#  'адам',
#  'а/кафіст',
#  'алілуjа',
#  'алмаз']

# %%
# filter out numeric values
morphemes_list = [s for s in morphemes_list if not s.isdigit()]

# %%
with open("../data/processed/merged_morfems_knu.txt", "w", encoding="utf-8") as file:
    for item in morphemes_list:
        file.write(f"{item}\n")
